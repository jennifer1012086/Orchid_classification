# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/中正大學/四下/機器學習/Project/orchid
# Out:
# /content/drive/.shortcut-targets-by-id/1_InfK01Bsid5YH4H8rWarK30q6DtCDZ1/orchid

# %%
import pandas as pd
from glob import glob
 
files = glob('private_*.csv')
# files.append('private_10000_15000.csv')
 
df = pd.concat((pd.read_csv(file) for file in files), ignore_index=True)
 
# print(df)

# %%
files
# Out:
# ['private_30000_35000.csv',
#  'private_35000_37500.csv',
#  'private_40000_.csv',
#  'private_37500_40000.csv',
#  'private_25000_27500.csv',
#  'private_27500_30000.csv',
#  'private_15000_20000.csv',
#  'private_5000_10000.csv',
#  'private_20000_21250.csv',
#  'private_21250_22500.csv',
#  'private_23750_25000.csv',
#  'private_0_5000.csv',
#  'private_22500_23750_yt.csv',
#  'private_10000_15000.csv']

# %%
len(df)
# Out:
# 41425

# %%
df.to_csv("./private.csv", index=False)

# %% [markdown]
# # Merge

# %%
files = ['public.csv', 'private.csv']
df = pd.concat((pd.read_csv(file) for file in files), ignore_index=True)
len(df)
# Out:
# 81710

# %%
df.to_csv("./merged.csv", index=False)
